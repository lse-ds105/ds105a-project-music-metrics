# %% [markdown]
# ```
#     pip install wordcloud
#     pip install nltk
#     pip install matplotlib
#     pip install plotnine
#     pip install everything_else_below
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# from wordcloud import WordCloud
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from plotnine import *
import plotnine as p9
import re
from scrapy import Selector
import requests as requests
import json
import statsmodels.api as sm

# %%
merged_df = pd.read_csv('../data/merged.csv')

# %%
def extract_artist_and_song(string):

    pattern_in_brackets = re.compile(r'\[.*?\]')
    pattern_in_parentheses = re.compile(r'\(.*?\)')

    string = re.sub(pattern_in_brackets, '', string)
    string = re.sub(pattern_in_parentheses, '', string)

    if '-' not in string:
        return 'None'
    if '-' in string:
        artist, song = string.split(' - ', 1)

    return [artist.strip(), song.strip()]

# %%
new_merge = merged_df

new_merge['Artist'] = merged_df['title'].apply(lambda x: extract_artist_and_song(x)[0])
new_merge['Song'] = merged_df['title'].apply(lambda x: extract_artist_and_song(x)[1])

new_merge.head()
# Out:
#    Unnamed: 0     video_id                                              title  \
# 0           0  kJQP7kiw5Fk            Luis Fonsi - Despacito ft. Daddy Yankee
# 1           1  JGwWNGJdvx8   Ed Sheeran - Shape of You (Official Music Video)
# 2           2  RgKAFK5djSk  Wiz Khalifa - See You Again ft. Charlie Puth [...
# 3           3  OPf0YbXqDm0  Mark Ronson - Uptown Funk (Official Video) ft....
# 4           4  09R8_2nJtjg            Maroon 5 - Sugar (Official Music Video)
#
#                  channel_id      channel_title  \
# 0  UCLp8RBhQHu9wSsq62j_Md6A      LuisFonsiVEVO
# 1  UC0C-w0YjGpqDXGB8IHb662A         Ed Sheeran
# 2  UCLxOm-UQ1gtyQgfz8Rn34iQ  Wiz Khalifa Music
# 3  UCmfFGTSsfJVu6CGvL8r75qg     MarkRonsonVEVO
# 4  UCN1hnUccO4FD5WfM7ithXaw        Maroon5VEVO
#
#                                          description  like_count  view_count  \
# 0  Despacito” disponible ya en todas las platafor...    52536208  8327497494
# 1  The official music video for Ed Sheeran - Shap...    32323299  6149151955
# 2  Download the new Furious 7 Soundtrack Deluxe V...    42261942  6108729902
# 3  Official Video for Uptown Funk by Mark Ronson ...    21086264  5098360660
# 4  Buy Sugar on iTunes: http://smarturl.it/M5V Si...    15906928  3972703093
#
#    comment_count                               wikipedia_categories  \
# 0        4228228  ['https://en.wikipedia.org/wiki/Music', 'https...
# 1        1146136  ['https://en.wikipedia.org/wiki/Music', 'https...
# 2        2177000  ['https://en.wikipedia.org/wiki/Hip_hop_music'...
# 3         605169  ['https://en.wikipedia.org/wiki/Hip_hop_music'...
# 4         418290  ['https://en.wikipedia.org/wiki/Music', 'https...
#
#         Artist                                               Song
# 0   Luis Fonsi                         Despacito ft. Daddy Yankee
# 1   Ed Sheeran                                       Shape of You
# 2  Wiz Khalifa  See You Again ft. Charlie Puth  Furious 7 Soun...
# 3  Mark Ronson                        Uptown Funk  ft. Bruno Mars
# 4     Maroon 5                                              Sugar

# %%
def generate_song_url(song_artist, song_title):
    '''
    Returns a string of the URL for the Genius page of the song

        Parameters:
            song_artist (str): The artist of the song
            song_title (str): The title of the song

        Returns:
            song_url (str): The URL for the Genius page of the song
    '''
    
    base_url = 'https://genius.com/'
    
    # format the artist name and song title
    song_artist = song_artist.replace('&', 'and')
    formatted_artist = song_artist.lower().replace(' ', '-')
    formatted_title = song_title.lower().replace(' ', '-')
    
    # generate the song URL by concatenating strings according to Genius formatting
    song_url = f'{base_url}{formatted_artist}-{formatted_title}-lyrics'

    return song_url

# %%
new_merge['Genius_URL'] = new_merge.apply(lambda row: generate_song_url(row['Artist'], row['Song']), axis=1)

new_merge.head()
# Out:
#    Unnamed: 0     video_id                                              title  \
# 0           0  kJQP7kiw5Fk            Luis Fonsi - Despacito ft. Daddy Yankee
# 1           1  JGwWNGJdvx8   Ed Sheeran - Shape of You (Official Music Video)
# 2           2  RgKAFK5djSk  Wiz Khalifa - See You Again ft. Charlie Puth [...
# 3           3  OPf0YbXqDm0  Mark Ronson - Uptown Funk (Official Video) ft....
# 4           4  09R8_2nJtjg            Maroon 5 - Sugar (Official Music Video)
#
#                  channel_id      channel_title  \
# 0  UCLp8RBhQHu9wSsq62j_Md6A      LuisFonsiVEVO
# 1  UC0C-w0YjGpqDXGB8IHb662A         Ed Sheeran
# 2  UCLxOm-UQ1gtyQgfz8Rn34iQ  Wiz Khalifa Music
# 3  UCmfFGTSsfJVu6CGvL8r75qg     MarkRonsonVEVO
# 4  UCN1hnUccO4FD5WfM7ithXaw        Maroon5VEVO
#
#                                          description  like_count  view_count  \
# 0  Despacito” disponible ya en todas las platafor...    52536208  8327497494
# 1  The official music video for Ed Sheeran - Shap...    32323299  6149151955
# 2  Download the new Furious 7 Soundtrack Deluxe V...    42261942  6108729902
# 3  Official Video for Uptown Funk by Mark Ronson ...    21086264  5098360660
# 4  Buy Sugar on iTunes: http://smarturl.it/M5V Si...    15906928  3972703093
#
#    comment_count                               wikipedia_categories  \
# 0        4228228  ['https://en.wikipedia.org/wiki/Music', 'https...
# 1        1146136  ['https://en.wikipedia.org/wiki/Music', 'https...
# 2        2177000  ['https://en.wikipedia.org/wiki/Hip_hop_music'...
# 3         605169  ['https://en.wikipedia.org/wiki/Hip_hop_music'...
# 4         418290  ['https://en.wikipedia.org/wiki/Music', 'https...
#
#         Artist                                               Song  \
# 0   Luis Fonsi                         Despacito ft. Daddy Yankee
# 1   Ed Sheeran                                       Shape of You
# 2  Wiz Khalifa  See You Again ft. Charlie Puth  Furious 7 Soun...
# 3  Mark Ronson                        Uptown Funk  ft. Bruno Mars
# 4     Maroon 5                                              Sugar
#
#                                           Genius_URL
# 0  https://genius.com/luis-fonsi-despacito-ft.-da...
# 1  https://genius.com/ed-sheeran-shape-of-you-lyrics
# 2  https://genius.com/wiz-khalifa-see-you-again-f...
# 3  https://genius.com/mark-ronson-uptown-funk--ft...
# 4           https://genius.com/maroon-5-sugar-lyrics

# %%
def scrape_lyrics(session, song_url):
    '''
    Returns a string of song lyrics, with each line separated by a new line

        Parameters:
            session (variable): The session that has been initialised for requesting from the Genius website
            song_url (str): The URL of the Genius page for the song

        Returns:
            lyrics (str): The lyrics of the song
    '''
    
    # use initialised session to enhance performance
    response = session.get(song_url)
    sel = Selector(text=response.text)
    
    # scrape lyrics into one large string
    raw_lyrics = ' '.join(sel.css('div.Lyrics__Container-sc-1ynbvzw-1.kUgSbL ::text').getall())

    # clean lyrics using regular expression to remove words in square brackets
    pattern = r'\[.*?\]'
    result_string = re.sub(pattern, '', raw_lyrics)
    lyrics = ' '.join(result_string.split())

    return lyrics

# %%
credentials_file_path = "../credentials.json"

with open(credentials_file_path, "r") as f:
    credentials = json.load(f)

# %%
my_session = requests.Session()

# %%
new_merge['lyrics'] = new_merge.apply(lambda row: scrape_lyrics(my_session, row['Genius_URL']), axis=1)

new_merge.head()
# Out:
#    Unnamed: 0     video_id                                              title  \
# 0           0  kJQP7kiw5Fk            Luis Fonsi - Despacito ft. Daddy Yankee
# 1           1  JGwWNGJdvx8   Ed Sheeran - Shape of You (Official Music Video)
# 2           2  RgKAFK5djSk  Wiz Khalifa - See You Again ft. Charlie Puth [...
# 3           3  OPf0YbXqDm0  Mark Ronson - Uptown Funk (Official Video) ft....
# 4           4  09R8_2nJtjg            Maroon 5 - Sugar (Official Music Video)
#
#                  channel_id      channel_title  \
# 0  UCLp8RBhQHu9wSsq62j_Md6A      LuisFonsiVEVO
# 1  UC0C-w0YjGpqDXGB8IHb662A         Ed Sheeran
# 2  UCLxOm-UQ1gtyQgfz8Rn34iQ  Wiz Khalifa Music
# 3  UCmfFGTSsfJVu6CGvL8r75qg     MarkRonsonVEVO
# 4  UCN1hnUccO4FD5WfM7ithXaw        Maroon5VEVO
#
#                                          description  like_count  view_count  \
# 0  Despacito” disponible ya en todas las platafor...    52536208  8327497494
# 1  The official music video for Ed Sheeran - Shap...    32323299  6149151955
# 2  Download the new Furious 7 Soundtrack Deluxe V...    42261942  6108729902
# 3  Official Video for Uptown Funk by Mark Ronson ...    21086264  5098360660
# 4  Buy Sugar on iTunes: http://smarturl.it/M5V Si...    15906928  3972703093
#
#    comment_count                               wikipedia_categories  \
# 0        4228228  ['https://en.wikipedia.org/wiki/Music', 'https...
# 1        1146136  ['https://en.wikipedia.org/wiki/Music', 'https...
# 2        2177000  ['https://en.wikipedia.org/wiki/Hip_hop_music'...
# 3         605169  ['https://en.wikipedia.org/wiki/Hip_hop_music'...
# 4         418290  ['https://en.wikipedia.org/wiki/Music', 'https...
#
#         Artist                                               Song  \
# 0   Luis Fonsi                         Despacito ft. Daddy Yankee
# 1   Ed Sheeran                                       Shape of You
# 2  Wiz Khalifa  See You Again ft. Charlie Puth  Furious 7 Soun...
# 3  Mark Ronson                        Uptown Funk  ft. Bruno Mars
# 4     Maroon 5                                              Sugar
#
#                                           Genius_URL  \
# 0  https://genius.com/luis-fonsi-despacito-ft.-da...
# 1  https://genius.com/ed-sheeran-shape-of-you-lyrics
# 2  https://genius.com/wiz-khalifa-see-you-again-f...
# 3  https://genius.com/mark-ronson-uptown-funk--ft...
# 4           https://genius.com/maroon-5-sugar-lyrics
#
#                                               lyrics
# 0
# 1  A club isn't the best place to find a lover So...
# 2
# 3
# 4  I'm hurting, baby, I'm broken down I need your...

# %%
new_merge2 = new_merge.dropna()

df = new_merge2[['Artist', 'Song', 'like_count', 'view_count', 'comment_count', 'lyrics']].dropna().drop_duplicates(subset = ['Song'])

df = df[df['lyrics'] != '']

df.head()
# Out:
#           Artist            Song  like_count  view_count  comment_count  \
# 1     Ed Sheeran    Shape of You    32323299  6149151955        1146136
# 4       Maroon 5           Sugar    15906928  3972703093         418290
# 5    OneRepublic  Counting Stars    17490906  3927278630         488707
# 6     Katy Perry            Roar    16595850  3918599134         774322
# 8  Justin Bieber           Sorry    16306693  3741548245         868546
#
#                                               lyrics
# 1  A club isn't the best place to find a lover So...
# 4  I'm hurting, baby, I'm broken down I need your...
# 5  Lately, I've been, I've been losin' sleep Drea...
# 6  I used to bite my tongue and hold my breath Sc...
# 8  You gotta go and get angry at all of my honest...

# %%
sid = SentimentIntensityAnalyzer()

def get_sentiment_score(lyric):
    scores = sid.polarity_scores(lyric)
    list = [scores['neg'], scores['neu'], scores['pos'], scores['compound']]
    return list

# %%
df['sentiment_positive'] = df['lyrics'].apply(lambda x: get_sentiment_score(x)[2])
df['sentiment_neutral'] = df['lyrics'].apply(lambda x: get_sentiment_score(x)[1])
df['sentiment_negative'] = df['lyrics'].apply(lambda x: get_sentiment_score(x)[0])
df['sentiment_compound'] = df['lyrics'].apply(lambda x: get_sentiment_score(x)[3])

df.head()
# Out:
#           Artist            Song  like_count  view_count  comment_count  \
# 1     Ed Sheeran    Shape of You    32323299  6149151955        1146136
# 4       Maroon 5           Sugar    15906928  3972703093         418290
# 5    OneRepublic  Counting Stars    17490906  3927278630         488707
# 6     Katy Perry            Roar    16595850  3918599134         774322
# 8  Justin Bieber           Sorry    16306693  3741548245         868546
#
#                                               lyrics  sentiment_positive  \
# 1  A club isn't the best place to find a lover So...               0.229
# 4  I'm hurting, baby, I'm broken down I need your...               0.289
# 5  Lately, I've been, I've been losin' sleep Drea...               0.040
# 6  I used to bite my tongue and hold my breath Sc...               0.175
# 8  You gotta go and get angry at all of my honest...               0.133
#
#    sentiment_neutral  sentiment_negative  sentiment_compound
# 1              0.757               0.014              0.9995
# 4              0.642               0.070              0.9988
# 5              0.856               0.104             -0.9831
# 6              0.779               0.047              0.9945
# 8              0.723               0.145              0.9039

# %%
def get_lexical_richness(lyric):
    total_words = len(lyric.split())
    unique_words = len(set(lyric.split()))
    lexical_richness = unique_words/total_words*100
    return round(lexical_richness)

# %%
df['lexical_richness'] = df['lyrics'].apply(lambda x: get_lexical_richness(x))

df.head()
# Out:
#           Artist            Song  like_count  view_count  comment_count  \
# 1     Ed Sheeran    Shape of You    32323299  6149151955        1146136
# 4       Maroon 5           Sugar    15906928  3972703093         418290
# 5    OneRepublic  Counting Stars    17490906  3927278630         488707
# 6     Katy Perry            Roar    16595850  3918599134         774322
# 8  Justin Bieber           Sorry    16306693  3741548245         868546
#
#                                               lyrics  sentiment_positive  \
# 1  A club isn't the best place to find a lover So...               0.229
# 4  I'm hurting, baby, I'm broken down I need your...               0.289
# 5  Lately, I've been, I've been losin' sleep Drea...               0.040
# 6  I used to bite my tongue and hold my breath Sc...               0.175
# 8  You gotta go and get angry at all of my honest...               0.133
#
#    sentiment_neutral  sentiment_negative  sentiment_compound  lexical_richness
# 1              0.757               0.014              0.9995                23
# 4              0.642               0.070              0.9988                29
# 5              0.856               0.104             -0.9831                21
# 6              0.779               0.047              0.9945                31
# 8              0.723               0.145              0.9039                35

# %%
df['song_length'] = df['lyrics'].apply(lambda x: len(x.split()))

df.head()
# Out:
#           Artist            Song  like_count  view_count  comment_count  \
# 1     Ed Sheeran    Shape of You    32323299  6149151955        1146136
# 4       Maroon 5           Sugar    15906928  3972703093         418290
# 5    OneRepublic  Counting Stars    17490906  3927278630         488707
# 6     Katy Perry            Roar    16595850  3918599134         774322
# 8  Justin Bieber           Sorry    16306693  3741548245         868546
#
#                                               lyrics  sentiment_positive  \
# 1  A club isn't the best place to find a lover So...               0.229
# 4  I'm hurting, baby, I'm broken down I need your...               0.289
# 5  Lately, I've been, I've been losin' sleep Drea...               0.040
# 6  I used to bite my tongue and hold my breath Sc...               0.175
# 8  You gotta go and get angry at all of my honest...               0.133
#
#    sentiment_neutral  sentiment_negative  sentiment_compound  \
# 1              0.757               0.014              0.9995
# 4              0.642               0.070              0.9988
# 5              0.856               0.104             -0.9831
# 6              0.779               0.047              0.9945
# 8              0.723               0.145              0.9039
#
#    lexical_richness  song_length
# 1                23          699
# 4                29          472
# 5                21          517
# 6                31          352
# 8                35          359

# %%
g = p9.ggplot(
    mapping = p9.aes(x = 'sentiment_compound'),
    data = df
) + \
geom_histogram(binwidth=0.05)

g
# Out:
# <Figure Size: (640 x 480)>

# %%
df['sentiment_compound_absolute'] = df['sentiment_compound'].abs()

df.head()
# Out:
#           Artist            Song  like_count  view_count  comment_count  \
# 1     Ed Sheeran    Shape of You    32323299  6149151955        1146136
# 4       Maroon 5           Sugar    15906928  3972703093         418290
# 5    OneRepublic  Counting Stars    17490906  3927278630         488707
# 6     Katy Perry            Roar    16595850  3918599134         774322
# 8  Justin Bieber           Sorry    16306693  3741548245         868546
#
#                                               lyrics  sentiment_positive  \
# 1  A club isn't the best place to find a lover So...               0.229
# 4  I'm hurting, baby, I'm broken down I need your...               0.289
# 5  Lately, I've been, I've been losin' sleep Drea...               0.040
# 6  I used to bite my tongue and hold my breath Sc...               0.175
# 8  You gotta go and get angry at all of my honest...               0.133
#
#    sentiment_neutral  sentiment_negative  sentiment_compound  \
# 1              0.757               0.014              0.9995
# 4              0.642               0.070              0.9988
# 5              0.856               0.104             -0.9831
# 6              0.779               0.047              0.9945
# 8              0.723               0.145              0.9039
#
#    lexical_richness  song_length  sentiment_compound_absolute
# 1                23          699                       0.9995
# 4                29          472                       0.9988
# 5                21          517                       0.9831
# 6                31          352                       0.9945
# 8                35          359                       0.9039

# %%
df.to_csv('../data/for_ruikai.csv')

# %%
corr_df = df[['like_count','view_count','comment_count', 'sentiment_positive', 'sentiment_neutral', 'sentiment_negative', 'sentiment_compound_absolute', 'lexical_richness', 'song_length']].corr()

# %%
corr_df2 = corr_df. \
        melt(ignore_index=False) \
        .reset_index()

corr_df2['rounded_value'] = corr_df2['value'].apply(lambda x: np.round(x, 2))

# %%
g = p9.ggplot(
        mapping = p9.aes('index', 'variable', fill = 'value'),
        data = corr_df2
    ) + \
        p9.geom_tile() + \
        p9.geom_label(
            p9.aes(label = 'rounded_value'),
            fill = 'white',
            size = 8
        ) + \
        p9.scale_fill_distiller() + \
        p9.theme_minimal() + \
        p9.labs(
            title = 'Correlation Matrix',
            x = '',
            y = ''
        ) + \
        p9.theme(
            axis_text_x = element_text(angle = 90)
        )

g
# Out:
# <Figure Size: (640 x 480)>

# %%
X = df[['view_count', 'comment_count', 'lexical_richness', 'sentiment_compound_absolute', 'song_length']]
Y = df['like_count']

X = sm.add_constant(X)

model = sm.OLS(Y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             like_count   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.717
# Method:                 Least Squares   F-statistic:                     14.67
# Date:                Fri, 08 Dec 2023   Prob (F-statistic):           2.23e-06
# Time:                        11:32:16   Log-Likelihood:                -451.04
# No. Observations:                  28   AIC:                             914.1
# Df Residuals:                      22   BIC:                             922.1
# Df Model:                           5
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        1.404e+06   3.69e+06      0.380      0.708   -6.26e+06    9.07e+06
# view_count                      0.0024      0.001      3.126      0.005       0.001       0.004
# comment_count                  10.6048      2.728      3.887      0.001       4.947      16.263
# lexical_richness             7.899e+04   7.19e+04      1.098      0.284   -7.02e+04    2.28e+05
# sentiment_compound_absolute -2.874e+06   2.15e+06     -1.338      0.195   -7.33e+06    1.58e+06
# song_length                  3248.2130   4212.254      0.771      0.449   -5487.468     1.2e+04
# ==============================================================================
# Omnibus:                        0.582   Durbin-Watson:                   1.832
# Prob(Omnibus):                  0.747   Jarque-Bera (JB):                0.496
# Skew:                           0.298   Prob(JB):                        0.780
# Kurtosis:                       2.733   Cond. No.                     2.24e+10
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.24e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
wordcloud = WordCloud().generate(df.iloc[0,5])

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\soong\Documents\LSE Academics\DS105A\Group Project\ds105a-project-dees-nuts\notebooks\visualisation_ruikai.ipynb Cell 24 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/soong/Documents/LSE%20Academics/DS105A/Group%20Project/ds105a-project-dees-nuts/notebooks/visualisation_ruikai.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> wordcloud = WordCloud().generate(df.iloc[0,5])
#       <a href='vscode-notebook-cell:/c%3A/Users/soong/Documents/LSE%20Academics/DS105A/Group%20Project/ds105a-project-dees-nuts/notebooks/visualisation_ruikai.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> plt.imshow(wordcloud, interpolation='bilinear')
#       <a href='vscode-notebook-cell:/c%3A/Users/soong/Documents/LSE%20Academics/DS105A/Group%20Project/ds105a-project-dees-nuts/notebooks/visualisation_ruikai.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> plt.axis("off")
#
# NameError: name 'WordCloud' is not defined
